# %%
import pandas as pd

# %%
lp = pd.read_csv("laptopPrice.csv")

# %%
lp
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
lp.isnull().sum()  # sum of all null values
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
lp.duplicated().sum()  # sum of all duplicate values
# Out:
# np.int64(21)

# %%
lp
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
lp.drop_duplicates(inplace=True) #used to save the dataset without storing it into new variable

# %%
lp
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
lp.duplicated().sum()  # sum of all duplicate values
# Out:
# np.int64(0)

# %%
lp.dropna(inplace=True)

# %%
lp
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
# fill null value
lp.fillna(0)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
lp.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
lp = lp.drop(['Touchscreen', 'msoffice', 'warranty'], axis=1)

# %%
lp
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
for col in [
    "brand",
    "processor_brand",
    "processor_name",
    "processor_gnrtn",
    "ram_gb",
    "ram_type",
    "ssd",
    "hdd",
    "os",
    "os_bit",
    "graphic_card_gb",
    "weight",
    "rating",
]:
    print(f"Unique values in {col}: {lp[col].unique()}")
# Out:
# Unique values in brand: ['ASUS' 'Lenovo' 'acer' 'Avita' 'HP' 'DELL' 'MSI' 'APPLE']
# Unique values in processor_brand: ['Intel' 'AMD' 'M1']
# Unique values in processor_name: ['Core i3' 'Core i5' 'Celeron Dual' 'Ryzen 5' 'Core i7' 'Core i9' 'M1'
#  'Pentium Quad' 'Ryzen 3' 'Ryzen 7' 'Ryzen 9']
# Unique values in processor_gnrtn: ['10th' 'Not Available' '11th' '7th' '8th' '9th' '4th' '12th']
# Unique values in ram_gb: ['4 GB' '8 GB' '16 GB' '32 GB']
# Unique values in ram_type: ['DDR4' 'LPDDR4' 'LPDDR4X' 'DDR5' 'DDR3' 'LPDDR3']
# Unique values in ssd: ['0 GB' '512 GB' '256 GB' '128 GB' '1024 GB' '2048 GB' '3072 GB']
# Unique values in hdd: ['1024 GB' '0 GB' '512 GB' '2048 GB']
# Unique values in os: ['Windows' 'DOS' 'Mac']
# Unique values in os_bit: ['64-bit' '32-bit']
# Unique values in graphic_card_gb: ['0 GB' '2 GB' '4 GB' '6 GB' '8 GB']
# Unique values in weight: ['Casual' 'ThinNlight' 'Gaming']
# Unique values in rating: ['2 stars' '3 stars' '4 stars' '5 stars' '1 star']

# %% [markdown]
# # Maping

# %%
brand_map = {
    "ASUS": 1,
    "Lenovo": 2,
    "acer": 3,
    "Avita": 4,
    "HP": 5,
    "DELL": 6,
    "MSI": 7,
    "APPLE": 8,
}
processor_brand_map = {"Intel": 1, "AMD": 2, "M1": 3}
processor_name_map = {
    "M1": 1,
    "Celeron Dual": 2,
    "Core i3": 3,
    "Core i5": 5,
    "Core i7": 7,
    "Core i9": 9,
    "Pentium Quad": 4,
    "Ryzen 3": 33,
    "Ryzen 5": 55,
    "Ryzen 7": 77,
    "Ryzen 9": 99,
}
processor_gnrtn_map = {
    "Not Available": 0,
    "4th": 4,
    "7th": 7,
    "8th": 8,
    "9th": 9,
    "10th": 10,
    "11th": 11,
    "12th": 12,
}
ram_gb_map = {"4 GB": 4, "8 GB": 8, "16 GB": 16, "32 GB": 32}
ram_type_map = {"DDR4": 44, "LPDDR4": 244, "LPDDR4X": 2447, "DDR5": 45, "DDR3": 43, "LPDDR3": 243}
ssd_map = {
    "0 GB": 0,
    "128 GB": 128,
    "256 GB": 256,
    "512 GB": 512,
    "1024 GB": 1024,
    "2048 GB": 2048,
    "3072 GB": 3072,
}
hdd_map = {"0 GB": 0, "512 GB": 512, "1024 GB": 1024, "2048 GB": 2048}
os_map = {"Windows": 1, "DOS": 2, "Mac": 3}
os_bit_map = {"64-bit": 64, "32-bit": 32}
graphic_card_gb_map = {"0 GB": 0, "2 GB": 2, "4 GB": 4, "6 GB": 6, "8 GB": 8}
weight_map = {"Casual": 1, "ThinNlight": 2, "Gaming": 3}
rating_map = {"1 star": 1, "2 stars": 2, "3 stars": 3, "4 stars": 4, "5 stars": 5}

# %% [markdown]
# mapping

# %%
lp["brand"] = lp["brand"].map(brand_map)
lp["processor_brand"] = lp["processor_brand"].map(processor_brand_map)
lp["processor_name"] = lp["processor_name"].map(processor_name_map)
lp["processor_gnrtn"] = lp["processor_gnrtn"].map(processor_gnrtn_map)
lp["ram_gb"] = lp["ram_gb"].map(ram_gb_map)
lp["ram_type"] = lp["ram_type"].map(ram_type_map)
lp["ssd"] = lp["ssd"].map(ssd_map)
lp["hdd"] = lp["hdd"].map(hdd_map)
lp["os"] = lp["os"].map(os_map)
lp["os_bit"] = lp["os_bit"].map(os_bit_map)
lp["graphic_card_gb"] = lp["graphic_card_gb"].map(graphic_card_gb_map)
lp["weight"] = lp["weight"].map(weight_map)
lp["rating"] = lp["rating"].map(rating_map)

# %%
lp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              802 non-null    int64
#  1   processor_brand    802 non-null    int64
#  2   processor_name     802 non-null    int64
#  3   processor_gnrtn    802 non-null    int64
#  4   ram_gb             802 non-null    int64
#  5   ram_type           802 non-null    int64
#  6   ssd                802 non-null    int64
#  7   hdd                802 non-null    int64
#  8   os                 802 non-null    int64
#  9   os_bit             802 non-null    int64
#  10  graphic_card_gb    802 non-null    int64
#  11  weight             802 non-null    int64
#  12  Price              802 non-null    int64
#  13  rating             802 non-null    int64
#  14  Number of Ratings  802 non-null    int64
#  15  Number of Reviews  802 non-null    int64
# dtypes: int64(16)
# ...

# %%
lp.head(30)
# Out:
#     brand  processor_brand  processor_name  processor_gnrtn  ram_gb  ram_type  \
# 0       1                1               3               10       4        44
# 1       2                1               3               10       4        44
# 2       2                1               3               10       4        44
# 3       1                1               5               10       8        44
# 4       1                1               2                0       4        44
# 5       1                1               2                0       4        44
# 6       1                1               2                0       4        44
# 7       1                1               5               10       8        44
# 8       2                1               5               10       4        44
# 9       3                2              55               10       4        44
# 10      3                2              55               10       4        44
# ...

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# obj
encoder = LabelEncoder()

# %%
output = encoder.fit_transform(lp["brand"])

# %%
output.shape
# Out:
# (802,)

# %%
output
# Out:
# array([0, 1, 1, 0, 0, 0, 0, 0, 1, 2, 2, 2, 3, 0, 4, 4, 1, 4, 1, 0, 0, 4,
#        4, 0, 1, 0, 0, 4, 5, 4, 2, 0, 0, 1, 1, 5, 0, 1, 5, 5, 1, 0, 1, 5,
#        1, 5, 5, 5, 5, 1, 0, 1, 1, 1, 1, 4, 6, 5, 0, 1, 1, 5, 2, 5, 0, 1,
#        0, 1, 0, 1, 4, 1, 0, 4, 5, 5, 1, 5, 1, 0, 5, 0, 0, 4, 0, 4, 4, 0,
#        0, 0, 0, 0, 1, 5, 4, 4, 0, 6, 4, 6, 0, 1, 0, 4, 4, 0, 5, 4, 5, 5,
#        0, 1, 4, 4, 4, 0, 4, 0, 0, 0, 0, 4, 4, 5, 1, 5, 4, 0, 1, 5, 5, 5,
#        4, 0, 5, 1, 0, 0, 5, 5, 1, 4, 4, 5, 4, 0, 4, 0, 0, 5, 0, 4, 5, 0,
#        5, 4, 1, 0, 2, 5, 0, 5, 0, 0, 0, 5, 0, 0, 5, 5, 5, 0, 5, 2, 5, 5,
#        5, 0, 5, 5, 5, 5, 5, 5, 0, 0, 4, 4, 1, 1, 1, 1, 2, 2, 2, 0, 5, 5,
#        4, 4, 1, 4, 1, 2, 0, 5, 2, 4, 2, 0, 1, 4, 4, 1, 4, 0, 1, 1, 1, 1,
#        0, 1, 2, 1, 0, 0, 1, 0, 6, 0, 6, 0, 5, 5, 1, 0, 4, 0, 4, 4, 2, 5,
#        0, 0, 5, 5, 0, 6, 4, 0, 1, 1, 4, 2, 0, 4, 5, 0, 4, 0, 1, 4, 5, 5,
#        0, 1, 1, 5, 1, 0, 1, 5, 6, 0, 1, 5, 1, 1, 0, 4, 1, 1, 4, 5, 1, 1,
# ...

# %%
lp["brand"] = output

# %%
lp
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               3               10       4
# 1        1                1               3               10       4
# 2        1                1               3               10       4
# 3        0                1               5               10       8
# 4        0                1               2                0       4
# ..     ...              ...             ...              ...     ...
# 818      0                2              99                0       4
# 819      0                2              99                0       4
# 820      0                2              99                0       4
# 821      0                2              99                0       4
# 822      1                2              55               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight   Price  \
# ...

# %%
lp.dtypes
# Out:
# brand                int64
# processor_brand      int64
# processor_name       int64
# processor_gnrtn      int64
# ram_gb               int64
# ram_type             int64
# ssd                  int64
# hdd                  int64
# os                   int64
# os_bit               int64
# graphic_card_gb      int64
# weight               int64
# Price                int64
# rating               int64
# Number of Ratings    int64
# Number of Reviews    int64
# dtype: object

# %%
x = lp.drop(["Price"], axis=1)
y = lp[["Price"]]
y  # dependent
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 1 columns]

# %%
x  # independent var
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        0                1               3               10       4
# 1        1                1               3               10       4
# 2        1                1               3               10       4
# 3        0                1               5               10       8
# 4        0                1               2                0       4
# ..     ...              ...             ...              ...     ...
# 818      0                2              99                0       4
# 819      0                2              99                0       4
# 820      0                2              99                0       4
# 821      0                2              99                0       4
# 822      1                2              55               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  rating  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)  # testsize how much data u want to keep for testing

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((641, 15), (161, 15), (641, 1), (161, 1))

# %%
x_train.head()
x_train.shape
# Out:
# (641, 15)

# %%
y_train.head()
y_train.shape
# Out:
# (641, 1)

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 196      2                1               5                0       8
# 299      0                1               5               11       8
# 171      5                1               3               10       8
# 537      4                1               7               10      16
# 551      6                1               7               11      16
# ..     ...              ...             ...              ...     ...
# 368      0                1               5               11       8
# 361      4                1               5               10       8
# 446      5                1               5               11       8
# 767      1                2              77                0       4
# 529      1                1               7               11      16
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  rating  \
# ...

# %%
y_test
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns]

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
obj = GradientBoostingClassifier()
obj.fit(x_train, y_train)
# Out:
# e:\coding\ProgrammingSoftware\PYTHON\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier()

# %%
# training and testing score
train_score = obj.score(X_train, y_train)
test_score = obj.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # training and testing score
# ----> 2 train_score = obj.score(X_train, y_train)
#       3 test_score = obj.score(X_test, y_test)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# # linear regresion
